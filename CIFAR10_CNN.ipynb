# %% [markdown]
# # CIFAR-10 CNN Classifier
#
# This notebook allows you to run the CIFAR-10 CNN project in Google Colab with free GPU access.

# %%
# Clone the repository
# !git clone https://github.com/arpitha9380/CNN.git
# %cd CNN

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Train the model
# !python main.py --mode both --epochs 50 --save-plots --batch-size 128

# %%
# Display results
from IPython.display import Image, display

print("Training History:")
display(Image("plots/training_history.png"))

print("\nConfusion Matrix:")
display(Image("plots/confusion_matrix.png"))

print("\nSample Predictions:")
display(Image("plots/predictions.png"))
